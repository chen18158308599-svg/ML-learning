# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

fig=plt.figure()
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.show()

# %%
fig.savefig('picture of sin.png')

# %%
from IPython.display import Image
Image('picture of sin.png')

# %%
plt.figure()
plt.subplot(2,1,1) #row,column,panel number
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

# %%
print(plt.gcf())
print(plt.gca())
# Out:
# Figure(640x480)
# Axes(0.125,0.11;0.775x0.77)

# %%
import numpy as np
x = np.linspace(0, 10, 100)
plt.figure()
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)
print(fig)
print(ax)
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))
plt.axis('tight')
# Out:
# Figure(640x480)
# [<Axes: > <Axes: >]
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.0999445244849302),
#  np.float64(1.0999973583088063))

# %%
import numpy as np
x = np.linspace(0, 10, 100)
plt.figure()
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)
print(fig)
print(ax)
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))
# Out:
# Figure(640x480)
# [<Axes: > <Axes: >]

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.xlim(-1,11)

plt.show()
